# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("UK_fleet_landings.csv")

# %%
data.head()
# Out:
#    year  month port_of_landing port_nationality vessel_nationality  \
# 0  2015      1       Aberdaran       UK - Wales         UK - Wales
# 1  2015      1       Aberdaran       UK - Wales         UK - Wales
# 2  2015      1       Aberdaran       UK - Wales         UK - Wales
# 3  2015      1       Aberdaran       UK - Wales         UK - Wales
# 4  2015      1        Aberdeen    UK - Scotland      UK - Scotland
#
#     length_group   gear_category species_code             species_name  \
# 0  10m and under  Pots and traps          BSS                     Bass
# 1  10m and under  Pots and traps          COD                      Cod
# 2  10m and under  Pots and traps          CRE  Crabs (C.P.Mixed Sexes)
# 3  10m and under  Pots and traps          LBE                 Lobsters
# 4  10m and under  Pots and traps          CRE  Crabs (C.P.Mixed Sexes)
#
#     species species_group  live_weight  landed_weight  value_gbp
# 0      Bass      Demersal        0.005          0.005       27.6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672256 entries, 0 to 672255
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   year                672256 non-null  int64
#  1   month               672256 non-null  int64
#  2   port_of_landing     672256 non-null  object
#  3   port_nationality    672256 non-null  object
#  4   vessel_nationality  672256 non-null  object
#  5   length_group        672256 non-null  object
#  6   gear_category       672256 non-null  object
#  7   species_code        672256 non-null  object
#  8   species_name        672256 non-null  object
#  9   species             672256 non-null  object
#  10  species_group       672239 non-null  object
#  11  live_weight         672256 non-null  float64
#  12  landed_weight       672256 non-null  float64
#  13  value_gbp           672256 non-null  float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 71.8+ MB

# %%
data.describe()
# Out:
#                 year          month    live_weight  landed_weight  \
# count  672256.000000  672256.000000  672256.000000  672256.000000
# mean     2011.517809       6.582897       8.607791       8.070248
# std         2.221101       3.334982     169.061854     168.123088
# min      2008.000000       1.000000      -0.020000      -0.020000
# 25%      2010.000000       4.000000       0.013300       0.012000
# 50%      2011.000000       7.000000       0.098000       0.089000
# 75%      2013.000000       9.000000       0.761100       0.691000
# max      2015.000000      12.000000   32942.735000   32942.735000
#
#           value_gbp
# count  6.722560e+05
# mean   9.999960e+03
# std    1.376504e+05
# min   -1.979290e+03
# 25%    2.437000e+01
# 50%    1.966500e+02
# 75%    1.687665e+03
# max    2.894126e+07

# %%
 list(data.columns)
# Out:
# ['year',
#  'month',
#  'port_of_landing',
#  'port_nationality',
#  'vessel_nationality',
#  'length_group',
#  'gear_category',
#  'species_code',
#  'species_name',
#  'species',
#  'species_group',
#  'live_weight',
#  'landed_weight',
#  'value_gbp']

# %%
dat = data[data.columns[0:4]].head(3)
dat
# Out:
#    year  month port_of_landing port_nationality
# 0  2015      1       Aberdaran       UK - Wales
# 1  2015      1       Aberdaran       UK - Wales
# 2  2015      1       Aberdaran       UK - Wales

# %%
new_dat = pd.DataFrame([np.arange(1,5)], columns= dat.columns, index=[3])
new_dat
# Out:
#    year  month  port_of_landing  port_nationality
# 3     1      2                3                 4

# %%
new_dat1 = pd.DataFrame(np.arange(0,3), columns=["new"], index=[4, 5, 6])
new_dat1
# Out:
#    new
# 4    0
# 5    1
# 6    2

# %%
pd.concat([dat, new_dat], axis=0)
# Out:
#    year  month port_of_landing port_nationality
# 0  2015      1       Aberdaran       UK - Wales
# 1  2015      1       Aberdaran       UK - Wales
# 2  2015      1       Aberdaran       UK - Wales
# 3     1      2               3                4

# %%
pd.concat([dat, new_dat1], axis=1)
# Out:
#      year  month port_of_landing port_nationality  new
# 0  2015.0    1.0       Aberdaran       UK - Wales  NaN
# 1  2015.0    1.0       Aberdaran       UK - Wales  NaN
# 2  2015.0    1.0       Aberdaran       UK - Wales  NaN
# 4     NaN    NaN             NaN              NaN  0.0
# 5     NaN    NaN             NaN              NaN  1.0
# 6     NaN    NaN             NaN              NaN  2.0

# %%
type(list(np.arange(1,6)))
# Out:
# list

# %%
data.groupby("year").mean()
# Out:
#          month  live_weight  landed_weight     value_gbp
# year
# 2008  6.610569    10.408608       9.652559  10405.897666
# 2009  6.532214     7.785875       7.159831   8667.989834
# 2010  6.611864     8.114550       7.601243   9339.766839
# 2011  6.619367     7.354895       6.887360  10324.845049
# 2012  6.533912     7.992684       7.537336   9763.250883
# 2013  6.612872     8.091195       7.612079   9569.405923
# 2014  6.571455    10.372996       9.839423  11732.209126
# 2015  6.577592     9.411905       8.895966  10488.085250

# %%
data["month"].mean()
# Out:
# 6.582896991622239
